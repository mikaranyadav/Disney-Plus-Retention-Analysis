# %%
pip install pandas numpy faker jupyter
# Out:
# Requirement already satisfied: pandas in c:\users\karan\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\karan\anaconda3\lib\site-packages (1.26.4)
# Collecting faker
#   Downloading faker-37.8.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: jupyter in c:\users\karan\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\karan\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karan\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karan\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: notebook in c:\users\karan\anaconda3\lib\site-packages (from jupyter) (7.0.8)
# Requirement already satisfied: qtconsole in c:\users\karan\anaconda3\lib\site-packages (from jupyter) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\karan\anaconda3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\karan\anaconda3\lib\site-packages (from jupyter) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\karan\anaconda3\lib\site-packages (from jupyter) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\karan\anaconda3\lib\site-packages (from jupyter) (7.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\karan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (23.2)
# Requirement already satisfied: psutil in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\karan\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\karan\anaconda3\lib\site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\karan\anaconda3\lib\site-packages (from ipywidgets->jupyter) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\karan\anaconda3\lib\site-packages (from ipywidgets->jupyter) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-console->jupyter) (3.0.43)
# Requirement already satisfied: pygments in c:\users\karan\anaconda3\lib\site-packages (from jupyter-console->jupyter) (2.15.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\karan\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\karan\anaconda3\lib\site-packages (from notebook->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\karan\anaconda3\lib\site-packages (from notebook->jupyter) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\karan\anaconda3\lib\site-packages (from notebook->jupyter) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\karan\anaconda3\lib\site-packages (from notebook->jupyter) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\karan\anaconda3\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\karan\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: decorator in c:\users\karan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\karan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\karan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: colorama in c:\users\karan\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\karan\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\karan\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\karan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\karan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\karan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\karan\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.32.2)
# Requirement already satisfied: fastjsonschema in c:\users\karan\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\karan\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\karan\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\karan\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\karan\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\karan\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\karan\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\karan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\karan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\karan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\karan\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\karan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\karan\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karan\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karan\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karan\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2024.7.4)
# Requirement already satisfied: executing in c:\users\karan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\karan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\karan\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\karan\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\karan\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\karan\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\karan\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.2.3)
# Downloading faker-37.8.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.0 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.0 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.0 MB 281.8 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/2.0 MB 409.6 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/2.0 MB 302.7 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/2.0 MB 302.7 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/2.0 MB 291.5 kB/s eta 0:00:07
#    -- ------------------------------------- 0.1/2.0 MB 295.4 kB/s eta 0:00:07
#    -- ------------------------------------- 0.1/2.0 MB 355.0 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.0 MB 353.1 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.0 MB 338.5 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.0 MB 338.0 kB/s eta 0:00:06
#    --- ------------------------------------ 0.2/2.0 MB 338.0 kB/s eta 0:00:06
#    ---- ----------------------------------- 0.2/2.0 MB 336.6 kB/s eta 0:00:06
#    ---- ----------------------------------- 0.2/2.0 MB 336.0 kB/s eta 0:00:06
#    ----- ---------------------------------- 0
1
# Note: you may need to restart the kernel to use updated packages.

# %%
# --- 1. Import Necessary Libraries ---
import pandas as pd
import numpy as np
from faker import Faker
import random
from datetime import datetime

# --- 2. Initialize and Configure ---
# Initialize the Faker library to generate fake data
fake = Faker()

# Set the number of subscribers you want to generate
num_users = 10000

print(f"Starting data generation for {num_users} subscribers...")

# Create an empty list to store each user's data
data = []

# --- 3. The Main Generation Loop ---
# This loop runs once for each subscriber we want to create
for _ in range(num_users):
    
    # --- A. Basic Subscriber Attributes ---
    country = random.choice(['Singapore', 'Malaysia', 'Indonesia', 'Thailand', 'Philippines', 'Vietnam'])
    plan_type = random.choice(['Basic', 'Standard', 'Premium'])
    age = random.randint(18, 65)
    subscription_date = fake.date_between(start_date='-2y', end_date='today')
    
    # --- B. Feature Engineering: Calculate Tenure ---
    # Calculate the number of months from subscription to now
    tenure_months = (datetime.now().year - subscription_date.year) * 12 + (datetime.now().month - subscription_date.month)
    # Ensure tenure is at least 1 month for new sign-ups
    if tenure_months <= 0:
        tenure_months = 1
        
    # --- C. Simulating User Engagement ---
    # Generate weekly watch hours from a normal (bell-curve) distribution
    # Average (loc) is 10 hours, standard deviation (scale) is 5 hours
    watch_hours_per_week = round(np.random.normal(loc=10, scale=5), 1)
    # Ensure watch hours are not negative
    if watch_hours_per_week < 0:
        watch_hours_per_week = 0.5

    # --- D. Simulating Churn with Business Logic ---
    # Start with a base churn probability for a loyal user
    churn_probability = 0.1

    # Rule 1: Tenure is the biggest factor
    if tenure_months < 3:
        churn_probability += 0.4  # High risk for new users
    elif tenure_months < 12:
        churn_probability += 0.15 # Medium risk for users under a year

    # Rule 2: Low engagement indicates churn risk
    if watch_hours_per_week < 5:
        churn_probability += 0.25
        
    # Rule 3: Basic plan users may be slightly less committed
    if plan_type == 'Basic':
        churn_probability += 0.05
    
    # Decide if the user churns based on the final probability
    # 1 = Churned, 0 = Did Not Churn
    churn = 1 if random.random() < churn_probability else 0

    # --- E. Assemble the Data for One User ---
    # Add the generated user's data as a dictionary to our list
    data.append({
        'user_id': fake.uuid4(),
        'age': age,
        'country': country,
        'plan_type': plan_type,
        'subscription_date': subscription_date,
        'tenure_months': tenure_months,
        'watch_hours_per_week': watch_hours_per_week,
        'churn': churn
    })

# --- 4. Final Conversion and Export ---
# Convert the list of user data into a pandas DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
# index=False prevents pandas from saving the row numbers as a column
df.to_csv('disney_plus_sea_subscribers.csv', index=False)

print("\nDataset generation complete!")
print(f"File saved as 'disney_plus_sea_subscribers.csv'")
print("\n--- Data Preview ---")
print(df.head())
# Out:
# Starting data generation for 10000 subscribers...
#
# Dataset generation complete!
# File saved as 'disney_plus_sea_subscribers.csv'
#
# --- Data Preview ---
#                                 user_id  age    country plan_type  \
# 0  4fd7c071-b749-42b5-b624-322dc97c457f   27  Singapore     Basic
# 1  b3e5b494-b852-4164-b870-58a874d91eb2   53   Thailand   Premium
# 2  e215f0a5-ab4b-4353-84fc-8a801f7b12ca   29  Singapore  Standard
# 3  fdac7b34-3532-416a-8cb4-3bab2b96c88a   27  Singapore   Premium
# 4  31430913-97d1-4fe2-b8af-86675a458c50   38   Malaysia     Basic
#
#   subscription_date  tenure_months  watch_hours_per_week  churn
# 0        2024-04-16             17                   6.5      0
# 1        2023-11-02             22                  12.0      0
# 2        2025-06-06              3                  15.6      0
# 3        2024-07-11             14                   8.1      0
# 4        2024-12-06              9                  11.4      1
